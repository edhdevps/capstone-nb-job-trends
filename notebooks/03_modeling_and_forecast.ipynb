# %% [markdown]
# # Modeling and Forecast
#
# This notebook builds a simple forecast model for Tech/STEM employment in New Brunswick.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.linear_model import LinearRegression

# %%
PROJECT_ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()

DATA_INTERIM = PROJECT_ROOT / "data" / "interim"
FIGURES = PROJECT_ROOT / "figures"

df = pd.read_parquet(DATA_INTERIM / "nb_employment_by_occupation.parquet")

print(df.shape)
df.head()
# Out:
# (1534, 8)
#    REF_DATE            GEO Labour force characteristics  \
# 0      2000  New Brunswick                   Employment
# 1      2000  New Brunswick                   Employment
# 2      2000  New Brunswick                   Employment
# 3      2000  New Brunswick                   Employment
# 4      2000  New Brunswick                   Employment
#
#           National Occupational Classification (NOC)          Gender  VALUE  \
# 0                     Total, all occupations [00-95]  Total - Gender  331.6
# 1  Management occupations [00, 10, 20, 30, 40, 50...  Total - Gender   29.6
# 2  Legislative and senior management occupations [0]  Total - Gender    1.0
# 3  Specialized middle management occupations [10,...  Total - Gender    8.0
# 4  Middle management occupations in retail and wh...  Total - Gender   13.6
#
#                                  NOC_CODE sector_group
# 0                                   00-95        Other
# ...

# %%
# Annual Tech_STEM employment data for New Brunswick
tech_df = (
    df[df["sector_group"] == "Tech_STEM"]
    .groupby("REF_DATE")["VALUE"]
    .sum()
    .reset_index()
)

tech_df.head()
# Out:
#    REF_DATE  VALUE
# 0      2000   40.2
# 1      2001   44.2
# 2      2002   43.3
# 3      2003   44.2
# 4      2004   48.5
